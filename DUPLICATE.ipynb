# %%
pip install pandasgui
# Out:
# ...
#
#   Using cached pandasgui-0.2.14-py3-none-any.whl
# ...
#   Using cached PyQtWebEngine-5.15.6-cp37-abi3-win_amd64.whl (182 kB)
# ...
#   Using cached wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# ...
#   Using cached qtstylish-0.1.5-py3-none-any.whl
# ...
#   Using cached matplotlib-3.8.2-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# ...
# Using cached wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
# Using cached matplotlib-3.8.2-cp39-cp39-win_amd64.whl (7.6 MB)
# ...

# %%
import pandas as pd

df = pd.read_csv("houses.csv")

df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
import dtale

# %%
dtale.show(df).open_browser()

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
from pandasgui import show

show(df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_10348\1986309750.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   show(df)
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_10348\1986309750.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   show(df)
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_10348\1986309750.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# ...

# %%
single_house = df.loc[df['price'].idxmax()]['id']

# %%
single_house
# Out:
# 6762700020

# %%
df.nlargest(5, "price")
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 9254         9890     31374     2.0           0     4  ...     13        8860
# 4411         9200     35069     2.0           0     0  ...     13        6200
# 1448         8000     23985     2.0           0     4  ...     12        6720
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.nsmallest(5, "price")
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0           0     0  ...      3         670
# 15293     16344     1.0           0     0  ...      5         780
# 465        5050     1.0           0     0  ...      4         430
# 16198      9975     1.0           0     0  ...      5         730
# 8274      10426     1.0           0     0  ...      6         860
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
import pandas as pd

df = pd.read_csv("ranges_duplicates.csv")

# %%
df = df.dropna()

df
# Out:
#     Measurement   Region   Range
# 0        881792   Europe    High
# 1        867134  America    High
# 2        241654     Asia     Low
# 3        456234   Europe  Middle
# 4        301892  America     Low
# 5        654132  America    High
# 6        540275     Asia  Middle
# 7        467122     Asia  Middle
# 8         68512   Europe     Low
# 9        867134  America    High
# 10       241654     Asia     Low
# 11       456234   Europe  Middle

# %%
df = df.reset_index()
df = df.drop("index", axis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 df = df.reset_index()
# ----> 2 df = df.drop("index", axis)
#
# NameError: name 'axis' is not defined
